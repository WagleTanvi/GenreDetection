# %% [markdown]
# # Exploratory Data Analysis (EDA) and Feature Extraction
#
# This jupyter notebook will explore the GTZAN dataset to gain familiarity with the data as well as extract features from the audio files

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
import librosa  #python audio processing library
import librosa.display
import IPython.display as ipd # listen to music in jupyter notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Load Dataset

# %%
import os
data_files = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if "wav" in filename:
            data_files.append(os.path.join(dirname, filename))
print(f"There are {len(data_files)} number of audio files in this dataset")
# Out:
# There are 1000 number of audio files in this dataset

# %% [markdown]
# ### Listening to and Visualizing Audio Files

# %%
ipd.Audio(data_files[0])

# %%
first_audio, sr = librosa.load(data_files[0]) # automatically resampled to 22050 can set sr=None to preserve the original sampling rate

# %%
librosa.display.waveplot(first_audio, alpha=0.5)
plt.title(data_files[0].split("/")[-1])
plt.ylim((-1,1))
plt.ylabel("Amplitude")

# %% [markdown]
# ## Understanding and Visualizing Features from Librosa
#
# We will test extracting features from the first audio file using librosa and visualize them

# %% [markdown]
# ### Root Mean Square Energy
#
# Root Mean Square Energy is essentially the sqaure root of the mean of the $amplitude^2$. We take each frame (a collection of data points) and obtain the root mean square of each.
# It is an indicator of loudness but less sensitive to outliers

# %%
FRAME_LENGTH = 1024 
HOP_LENGTH = 512

rms_first_audio = librosa.feature.rms(first_audio, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH)[0]
print(f"The RSME of the first audio file is: {rms_first_audio}")
frames = range(len(rms_first_audio))
t = librosa.frames_to_time(frames, hop_length=HOP_LENGTH)
librosa.display.waveplot(first_audio, alpha=0.5)
plt.plot(t, rms_first_audio, color='green')
plt.title(data_files[0].split("/")[-1])
plt.ylim((-1,1))
plt.ylabel("Amplitude");

# %% [markdown]
# ### Zero Crossing Rate
#
# The number of times the signal crosses the horizontal axis. It is calculated by checking the difference between subsequent samples. In the sample below, it is normalized It can be a measure of "lack of smoothness" and "percussiveness" in the audio sample.

# %%
FRAME_LENGTH = 1024 
HOP_LENGTH = 512

zero_first_audio = librosa.feature.zero_crossing_rate(first_audio, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH)[0]
print(f"The Zero Crossing Rate of the first audio file is: {zero_first_audio}")
frames = range(len(zero_first_audio))
t = librosa.frames_to_time(frames, hop_length=HOP_LENGTH)
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
librosa.display.waveplot(first_audio, alpha=0.5)
plt.plot(t, zero_first_audio, color='orange')
plt.title(data_files[0].split("/")[-1])
plt.ylim((-1,1))

plt.subplot(2,2,2)
plt.plot(t, zero_first_audio, color='orange')
plt.title(data_files[0].split("/")[-1])
plt.ylim((0,1))

# %% [markdown]
# # Feature Extraction
# * Mel-frequency cepstral coefficients (MFCCs) = the way humans perceive sound
# * Spectral Centroid - where most of the energy is concentrated; "brightness of sound"; calculated as the weighted mean of the frequencies
# * Spectral Bandwidth - Variance from the Spectral Centroid; calculated as the weighted distances from the spectral centroid
# * Tempo - beats per minute

# %%
FRAME_LENGTH = 1024 
HOP_LENGTH = 512

# %%
def calculate_mean(arr):
    if len(arr) == 0:
        return None
    else: 
        return sum(arr)/ len (arr)

# %%
def extract_features(file_name):
    try: 
        audio, sr = librosa.load(file_name)
    except Exception: 
        print(f"Error occured while loading {file_name}")
        return None
    rmse_arr = librosa.feature.rms(audio, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH)[0]
    zcr_arr = librosa.feature.zero_crossing_rate(audio, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH)[0]
    mfcc_arr = librosa.feature.mfcc(audio, n_mfcc=13, sr=sr)[0]
    cent_arr = librosa.feature.spectral_centroid(audio, sr=sr, n_fft=FRAME_LENGTH, hop_length=HOP_LENGTH)[0]
    spec_band = librosa.feature.spectral_bandwidth(audio, sr=sr, n_fft=FRAME_LENGTH, hop_length=HOP_LENGTH)[0]
    chroma = librosa.feature.chroma_stft(audio, sr=sr, n_fft=FRAME_LENGTH, hop_length=HOP_LENGTH)[0]
    tempo = librosa.beat.tempo(audio, sr=sr, hop_length=HOP_LENGTH)[0]
    harmonic = librosa.effects.harmonic(audio)[0]
    percussive = librosa.effects.percussive(audio)[0]
    return [file_name, file_name.split("/")[-1], 
            rmse_arr, calculate_mean(rmse_arr), 
            zcr_arr, calculate_mean(zcr_arr), 
            mfcc_arr, calculate_mean(mfcc_arr), 
            cent_arr, calculate_mean(cent_arr), 
            spec_band, calculate_mean(spec_band), 
            chroma, calculate_mean(chroma),
            tempo, harmonic, percussive]

# %%
extracted_data = []
x = 0
for i in data_files:
    features = extract_features(i)
    if features: 
        extracted_data.append(features)
    x+=1
    print(f"Processed {x} features")
        
cols = ["File Path", "File Name", "rmse","zcr","mfcc", "spec_cent", "spec_band", "chroma", "tempo", "harmonic", "percussive"]
cols_new = [cols[0], cols[1]]
for x in range(2, len(cols)):
    cols_new.append(cols[x])
    if cols[x] != "harmonic" and cols[x] != "percussive" and cols[x] != "tempo": 
        cols_new.append(cols[x]+"_mean")
print(cols_new)
df = pd.DataFrame(extracted_data, columns=cols_new)
df.set_index('File Path', inplace=True)
# Out:
# Processed 1 features
# Processed 2 features
# Processed 3 features
# Processed 4 features
# Processed 5 features
# Processed 6 features
# Processed 7 features
# Processed 8 features
# Processed 9 features
# Processed 10 features
# Processed 11 features
# Processed 12 features
# Processed 13 features
# Processed 14 features
# Processed 15 features
# Processed 16 features
# Processed 17 features
# Processed 18 features
# Processed 19 features
# Processed 20 features
# Processed 21 features
# Processed 22 features
# Processed 23 features
# Processed 24 features
# Processed 25 features
# Processed 26 features
# Processed 27 features
# Processed 28 features
# Processed 29 features
# Processed 30 features
# Processed 31 features
# Processed 32 features
# Processed 33 features
# Processed 34 features
# Processed 35 features
# Processed 36 features
# Processed 37 features
# Processed 38 features
# Processed 39 features
# Processed 40 features
# Processed 41 features
# Processed 42 features
# Processed 43 features
# Processed 44 features
# Processed 45 features
# Processed 46 features
# Processed 47 features
# Processed 48 features
# Processed 49 features
# Processed 50 features
# Processed 51 features
# Processed 52 features
# Processed 53 features
# Processed 54 features
# Processed 55 features
# Processed 56 features
# Processed 57 features
# Processed 58 features
# Processed 59 features
# Processed 60 features
# Processed 61 features
# Processed 62 features
# Processed 63 features
# Processed 64 features
# Processed 65 features
# Processed 66 features
# Processed 67 features
# Processed 68 features
# Processed 69 features
# Processed 70 features
# Processed 71 features
# Processed 72 features
# Processed 73 features
# Processed 74 features
# Processed 75 features
# Processed 76 features
# Processed 77 features
# Processed 78 features
# Processed 79 features
# Processed 80 features
# Processed 81 features
# Processed 82 features
# Processed 83 features
# Processed 84 features
# Processed 85 features
# Processed 86 features
# Processed 87 features
# Processed 88 features
# Processed 89 features
# Processed 90 features
# Processed 91 features
# Processed 92 features
# Processed 93 features
# Processed 94 features
# Processed 95 features
# Processed 96 features
# Processed 97 features
# Processed 98 features
# Processed 99 features
# Processed 100 features
# Processed 101 features
# Processed 102 features
# Processed 103 features
# Processed 104 features
# Processed 105 features
# Processed 106 features
# Processed 107 features
# Processed 108 features
# Processed 109 features
# Processed 110 features
# Processed 111 features
# Processed 112 features
# Processed 113 features
# Processed 114 features
# Processed 115 features
# Processed 116 features
# Processed 117 features
# Processed 118 features
# Processed 119 features
# Processed 120 features
# Processed 121 features
# Processed 122 features
# Processed 123 features
# Processed 124 features
# Processed 125 features
# Processed 126 features
# Processed 127 features
# Processed 128 features
# Processed 129 features
# Processed 130 features
# Processed 131 features
# Processed 132 features
# Processed 133 features
# Processed 134 features
# Processed 135 features
# Processed 136 features
# Processed 137 features
# Processed 138 features
# Processed 139 features
# Processed 140 features
# Processed 141 features
# Processed 142 features
# Processed 143 features
# Processed 144 features
# Processed 145 features
# Processed 146 features
# Processed 147 features
# Processed 148 features
# Processed 149 features
# Processed 150 features
# Processed 151 features
# Processed 152 features
# Processed 153 features
# Processed 154 features
# Processed 155 features
# Processed 156 features
# Processed 157 features
# Processed 158 features
# Processed 159 features
# Processed 160 features
# Processed 161 features
# Processed 162 features
# Processed 163 features
# Processed 164 features
# Processed 165 features
# Processed 166 features
# Processed 167 features
# Processed 168 features
# Processed 169 features
# Processed 170 features
# Processed 171 features
# Processed 172 features
# Processed 173 features
# Processed 174 features
# Processed 175 features
# Processed 176 features
# Processed 177 features
# Processed 178 features
# Processed 179 features
# Processed 180 features
# Processed 181 features
# Processed 182 features
# Processed 183 features
# Processed 184 features
# Processed 185 features
# Processed 186 features
# Processed 187 features
# Processed 188 features
# Processed 189 features
# Processed 190 features
# Processed 191 features
# Processed 192 features
# Processed 193 features
# Processed 194 features
# Processed 195 features
# Processed 196 features
# Processed 197 features
# Processed 198 features
# Processed 199 features
# Processed 200 features
# Processed 201 features
# Processed 202 features
# Processed 203 features
# Processed 204 features
# Processed 205 features
# Processed 206 features
# Processed 207 features
# Processed 208 features
# Processed 209 features
# Processed 210 features
# Processed 211 features
# Processed 212 features
# Processed 213 features
# Processed 214 features
# Processed 215 features
# Processed 216 features
# Processed 217 features
# Processed 218 features
# Processed 219 features
# Processed 220 features
# Processed 221 features
# Processed 222 features
# Processed 223 features
# Processed 224 features
# Processed 225 features
# Processed 226 features
# Processed 227 features
# Processed 228 features
# Processed 229 features
# Processed 230 features
# Processed 231 features
# Processed 232 features
# Processed 233 features
# Processed 234 features
# Processed 235 features
# Processed 236 features
# Processed 237 features
# Processed 238 features
# Processed 239 features
# Processed 240 features
# Processed 241 features
# Processed 242 features
# Processed 243 features
# Processed 244 features
# Processed 245 features
# Processed 246 features
# Processed 247 features
# Processed 248 features
# Processed 249 features
# Processed 250 features
# Processed 251 features
# Processed 252 features
# Processed 253 features
# Processed 254 features
# Processed 255 features
# Processed 256 features
# Processed 257 features
# Processed 258 features
# Processed 259 features
# Processed 260 features
# Processed 261 features
# Processed 262 features
# Processed 263 features
# Processed 264 features
# Processed 265 features
# Processed 266 features
# Processed 267 features
# Processed 268 features
# Processed 269 features
# Processed 270 features
# Processed 271 features
# Processed 272 features
# Processed 273 features
# Processed 274 features
# Processed 275 features
# Processed 276 features
# Processed 277 features
# Processed 278 features
# Processed 279 features
# Processed 280 features
# Processed 281 features
# Processed 282 features
# Processed 283 features
# Processed 284 features
# Processed 285 features
# Processed 286 features
# Processed 287 features
# Processed 288 features
# Processed 289 features
# Processed 290 features
# Processed 291 features
# Processed 292 features
# Processed 293 features
# Processed 294 features
# Processed 295 features
# Processed 296 features
# Processed 297 features
# Processed 298 features
# Processed 299 features
# Processed 300 features
# Processed 301 features
# Processed 302 features
# Processed 303 features
# Processed 304 features
# Processed 305 features
# Processed 306 features
# Processed 307 features
# Processed 308 features
# Processed 309 features
# Processed 326 features
# Processed 327 features
# Processed 328 features
# Processed 329 features
# Processed 330 features
# Processed 331 features
# Processed 332 features
# Processed 333 features
# Processed 334 features
# Processed 335 features
# Processed 336 features
# Processed 337 features
# Processed 338 features
# Processed 339 features
# Processed 340 features
# Processed 341 features
# Processed 342 features
# Processed 343 features
# Processed 344 features
# Processed 345 features
# Processed 346 features
# Processed 347 features
# Processed 348 features
# Processed 349 features
# Processed 350 features
# Processed 351 features
# Processed 352 features
# Processed 353 features
# Processed 354 features
# Processed 355 features
# Processed 356 features
# Processed 357 features
# Processed 358 features
# Processed 359 features
# Processed 360 features
# Processed 361 features
# Processed 362 features
# Processed 363 features
# Processed 364 features
# Processed 365 features
# Processed 366 features
# Processed 367 features
# Processed 368 features
# Processed 369 features
# Processed 370 features
# Processed 371 features
# Processed 372 features
# Processed 373 features
# Processed 374 features
# Processed 375 features
# Processed 376 features
# Processed 377 features
# Processed 378 features
# Processed 379 features
# Processed 380 features
# Processed 381 features
# Processed 382 features
# Processed 383 features
# Processed 384 features
# Processed 385 features
# Processed 386 features
# Processed 387 features
# Processed 388 features
# Processed 389 features
# Processed 390 features
# Processed 391 features
# Processed 392 features
# Processed 393 features
# Processed 394 features
# Processed 395 features
# Processed 396 features
# Processed 397 features
# Processed 398 features
# Processed 399 features
# Processed 400 features
# Processed 401 features
# Processed 402 features
# Processed 403 features
# Processed 404 features
# Processed 405 features
# Processed 406 features
# Processed 407 features
# Processed 408 features
# Processed 409 features
# Processed 410 features
# Processed 411 features
# Processed 412 features
# Processed 413 features
# Processed 414 features
# Processed 415 features
# Processed 416 features
# Processed 417 features
# Processed 418 features
# Processed 419 features
# Processed 420 features
# Processed 421 features
# Processed 422 features
# Processed 423 features
# Processed 424 features
# Processed 425 features
# Processed 426 features
# Processed 427 features
# Processed 428 features
# Processed 429 features
# Processed 430 features
# Processed 431 features
# Processed 432 features
# Processed 433 features
# Processed 434 features
# Processed 435 features
# Processed 436 features
# Processed 437 features
# Processed 438 features
# Processed 439 features
# Processed 440 features
# Processed 441 features
# Processed 442 features
# Processed 443 features
# Processed 444 features
# Processed 445 features
# Processed 446 features
# Processed 447 features
# Processed 448 features
# Processed 449 features
# Processed 450 features
# Processed 451 features
# Processed 452 features
# Processed 453 features
# Processed 454 features
# Processed 455 features
# Processed 456 features
# Processed 457 features
# Processed 458 features
# Processed 459 features
# Processed 460 features
# Processed 461 features
# Processed 462 features
# Processed 463 features
# Processed 464 features
# Processed 465 features
# Processed 466 features
# Processed 467 features
# Processed 468 features
# Processed 469 features
# Processed 470 features
# Processed 471 features
# Processed 472 features
# Processed 473 features
# Processed 474 features
# Processed 475 features
# Processed 476 features
# Processed 477 features
# Processed 478 features
# Processed 479 features
# Processed 480 features
# Processed 481 features
# Processed 482 features
# Processed 483 features
# Processed 484 features
# Processed 485 features
# Processed 486 features
# Processed 487 features
# Processed 488 features
# Processed 489 features
# Processed 490 features
# Processed 491 features
# Processed 492 features
# Processed 493 features
# Processed 494 features
# Processed 495 features
# Processed 496 features
# Processed 497 features
# Processed 498 features
# Processed 499 features
# Processed 500 features
# Processed 501 features
# Processed 502 features
# Processed 503 features
# Processed 504 features
# Processed 505 features
# Processed 506 features
# Processed 507 features
# Processed 508 features
# Processed 509 features
# Processed 510 features
# Processed 511 features
# Processed 512 features
# Processed 513 features
# Processed 514 features
# Processed 515 features
# Processed 516 features
# Processed 517 features
# Processed 518 features
# Processed 519 features
# Processed 520 features
# Processed 521 features
# Processed 522 features
# Processed 523 features
# Processed 524 features
# Processed 525 features
# Processed 526 features
# Processed 527 features
# Processed 528 features
# Processed 529 features
# Processed 530 features
# Processed 531 features
# Processed 532 features
# Processed 533 features
# Processed 554 features
# Processed 555 features
# Processed 556 features
# Processed 557 features
# Processed 558 features
# Processed 559 features
# Processed 560 features
# Processed 561 features
# Processed 562 features
# Processed 563 features
# Processed 564 features
# Processed 565 features
# Processed 566 features
# Processed 567 features
# Processed 568 features
# Processed 569 features
# Processed 570 features
# Processed 571 features
# Processed 572 features
# Processed 573 features
# Processed 574 features
# Processed 575 features
# Processed 576 features
# Processed 577 features
# Processed 578 features
# Processed 579 features
# Processed 580 features
# Processed 581 features
# Processed 582 features
# Processed 583 features
# Processed 584 features
# Processed 585 features
# Processed 586 features
# Processed 587 features
# Processed 588 features
# Processed 589 features
# Processed 590 features
# Processed 591 features
# Processed 592 features
# Processed 593 features
# Processed 594 features
# Processed 595 features
# Processed 596 features
# Processed 597 features
# Processed 598 features
# Processed 599 features
# Processed 600 features
# Processed 601 features
# Processed 602 features
# Processed 603 features
# Processed 604 features
# Processed 605 features
# Processed 606 features
# Processed 607 features
# Processed 608 features
# Processed 609 features
# Processed 610 features
# Processed 611 features
# Processed 612 features
# Processed 613 features
# Processed 614 features
# Processed 615 features
# Processed 616 features
# Processed 617 features
# Processed 618 features
# Processed 619 features
# Processed 620 features
# Processed 621 features
# Processed 622 features
# Processed 623 features
# Processed 624 features
# Processed 625 features
# Processed 626 features
# /opt/conda/lib/python3.7/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Error occured while loading /kaggle/input/gtzan-dataset-music-genre-classification/Data/genres_original/jazz/jazz.00054.wav
# Processed 627 features
# Processed 628 features
# Processed 629 features
# Processed 630 features
# Processed 631 features
# Processed 632 features
# Processed 633 features
# Processed 634 features
# Processed 635 features
# Processed 636 features
# Processed 637 features
# Processed 638 features
# Processed 639 features
# Processed 640 features
# Processed 641 features
# Processed 642 features
# Processed 643 features
# Processed 644 features
# Processed 645 features
# Processed 646 features
# Processed 647 features
# Processed 648 features
# Processed 649 features
# Processed 650 features
# Processed 651 features
# Processed 652 features
# Processed 653 features
# Processed 654 features
# Processed 655 features
# Processed 656 features
# Processed 657 features
# Processed 658 features
# Processed 659 features
# Processed 660 features
# Processed 661 features
# Processed 662 features
# Processed 663 features
# Processed 664 features
# Processed 665 features
# Processed 666 features
# Processed 667 features
# Processed 668 features
# Processed 669 features
# Processed 670 features
# Processed 671 features
# Processed 672 features
# Processed 673 features
# Processed 674 features
# Processed 675 features
# Processed 676 features
# Processed 677 features
# Processed 678 features
# Processed 679 features
# Processed 680 features
# Processed 681 features
# Processed 682 features
# Processed 683 features
# Processed 684 features
# Processed 685 features
# Processed 686 features
# Processed 687 features
# Processed 688 features
# Processed 689 features
# Processed 690 features
# Processed 691 features
# Processed 692 features
# Processed 693 features
# Processed 694 features
# Processed 695 features
# Processed 696 features
# Processed 697 features
# Processed 698 features
# Processed 699 features
# Processed 700 features
# Processed 701 features
# Processed 702 features
# Processed 703 features
# Processed 704 features
# Processed 705 features
# Processed 706 features
# Processed 707 features
# Processed 708 features
# Processed 709 features
# Processed 710 features
# Processed 711 features
# Processed 712 features
# Processed 713 features
# Processed 714 features
# Processed 715 features
# Processed 716 features
# Processed 717 features
# Processed 718 features
# Processed 719 features
# Processed 720 features
# Processed 721 features
# Processed 722 features
# Processed 723 features
# Processed 724 features
# Processed 725 features
# Processed 726 features
# Processed 727 features
# Processed 728 features
# Processed 729 features
# Processed 730 features
# Processed 731 features
# Processed 732 features
# Processed 733 features
# Processed 734 features
# Processed 735 features
# Processed 736 features
# Processed 737 features
# Processed 738 features
# Processed 739 features
# Processed 740 features
# Processed 741 features
# Processed 742 features
# Processed 743 features
# Processed 744 features
# Processed 745 features
# Processed 746 features
# Processed 747 features
# Processed 748 features
# Processed 749 features
# Processed 750 features
# Processed 751 features
# Processed 752 features
# Processed 753 features
# Processed 754 features
# Processed 755 features
# Processed 756 features
# Processed 757 features
# Processed 758 features
# Processed 759 features
# Processed 760 features
# Processed 761 features
# Processed 762 features
# Processed 763 features
# Processed 764 features
# Processed 765 features
# Processed 766 features
# Processed 767 features
# Processed 768 features
# Processed 769 features
# Processed 770 features
# Processed 771 features
# Processed 772 features
# Processed 773 features
# Processed 774 features
# Processed 775 features
# Processed 776 features
# Processed 777 features
# Processed 778 features
# Processed 779 features
# Processed 780 features
# Processed 781 features
# Processed 782 features
# Processed 783 features
# Processed 784 features
# Processed 785 features
# Processed 786 features
# Processed 787 features
# Processed 788 features
# Processed 789 features
# Processed 790 features
# Processed 791 features
# Processed 792 features
# Processed 793 features
# Processed 794 features
# Processed 795 features
# Processed 796 features
# Processed 797 features
# Processed 798 features
# Processed 799 features
# Processed 800 features
# Processed 801 features
# Processed 802 features
# Processed 803 features
# Processed 804 features
# Processed 805 features
# Processed 806 features
# Processed 807 features
# Processed 808 features
# Processed 809 features
# Processed 810 features
# Processed 811 features
# Processed 812 features
# Processed 813 features
# Processed 814 features
# Processed 815 features
# Processed 816 features
# Processed 817 features
# Processed 818 features
# Processed 819 features
# Processed 820 features
# Processed 821 features
# Processed 822 features
# Processed 823 features
# Processed 824 features
# Processed 825 features
# Processed 826 features
# Processed 827 features
# Processed 828 features
# Processed 829 features
# Processed 830 features
# Processed 831 features
# Processed 832 features
# Processed 833 features
# Processed 834 features
# Processed 835 features
# Processed 836 features
# Processed 837 features
# Processed 838 features
# Processed 839 features
# Processed 840 features
# Processed 841 features
# Processed 842 features
# Processed 843 features
# Processed 844 features
# Processed 845 features
# Processed 846 features
# Processed 847 features
# Processed 848 features
# Processed 849 features
# Processed 850 features
# Processed 851 features
# Processed 852 features
# Processed 853 features
# Processed 854 features
# Processed 855 features
# Processed 856 features
# Processed 857 features
# Processed 858 features
# Processed 859 features
# Processed 860 features
# Processed 861 features
# Processed 862 features
# Processed 863 features
# Processed 864 features
# Processed 865 features
# Processed 866 features
# Processed 867 features
# Processed 868 features
# Processed 869 features
# Processed 870 features
# Processed 871 features
# Processed 872 features
# Processed 873 features
# Processed 874 features
# Processed 875 features
# Processed 876 features
# Processed 877 features
# Processed 878 features
# Processed 879 features
# Processed 880 features
# Processed 881 features
# Processed 882 features
# Processed 883 features
# Processed 884 features
# Processed 885 features
# Processed 886 features
# Processed 887 features
# Processed 888 features
# Processed 889 features
# Processed 890 features
# Processed 891 features
# Processed 892 features
# Processed 893 features
# Processed 894 features
# Processed 895 features
# Processed 896 features
# Processed 897 features
# Processed 898 features
# Processed 899 features
# Processed 900 features
# Processed 901 features
# Processed 902 features
# Processed 903 features
# Processed 904 features
# Processed 905 features
# Processed 906 features
# Processed 907 features
# Processed 908 features
# Processed 909 features
# Processed 910 features
# Processed 911 features
# Processed 912 features
# Processed 913 features
# Processed 914 features
# Processed 915 features
# Processed 916 features
# Processed 917 features
# Processed 918 features
# Processed 919 features
# Processed 920 features
# Processed 921 features
# Processed 922 features
# Processed 923 features
# Processed 924 features
# Processed 925 features
# Processed 926 features
# Processed 927 features
# Processed 928 features
# Processed 929 features
# Processed 930 features
# Processed 931 features
# Processed 932 features
# Processed 933 features
# Processed 934 features
# Processed 935 features
# Processed 936 features
# Processed 937 features
# Processed 938 features
# Processed 939 features
# Processed 940 features
# Processed 941 features
# Processed 942 features
# Processed 943 features
# Processed 944 features
# Processed 945 features
# Processed 946 features
# Processed 947 features
# Processed 948 features
# Processed 949 features
# Processed 950 features
# Processed 951 features
# Processed 952 features
# Processed 953 features
# Processed 954 features
# Processed 955 features
# Processed 956 features
# Processed 957 features
# Processed 958 features
# Processed 959 features
# Processed 960 features
# Processed 961 features
# Processed 962 features
# Processed 963 features
# Processed 964 features
# Processed 965 features
# Processed 966 features
# Processed 967 features
# Processed 968 features
# Processed 969 features
# Processed 970 features
# Processed 971 features
# Processed 972 features
# Processed 973 features
# Processed 974 features
# Processed 975 features
# Processed 976 features
# Processed 977 features
# Processed 978 features
# Processed 979 features
# Processed 980 features
# Processed 981 features
# Processed 982 features
# Processed 983 features
# Processed 984 features
# Processed 985 features
# Processed 986 features
# Processed 987 features
# Processed 988 features
# Processed 989 features
# Processed 990 features
# Processed 991 features
# Processed 992 features
# Processed 993 features
# Processed 994 features
# Processed 995 features
# Processed 996 features
# Processed 997 features
# Processed 998 features
# Processed 999 features
# Processed 1000 features
# ['File Path', 'File Name', 'rmse', 'rmse_mean', 'zcr', 'zcr_mean', 'mfcc', 'mfcc_mean', 'spec_cent', 'spec_cent_mean', 'spec_band', 'spec_band_mean', 'chroma', 'chroma_mean', 'tempo', 'harmonic', 'percussive']

# %%
df.shape
# Out:
# (999, 16)

# %%
df.to_csv("/kaggle/working/data.csv")

# %% [markdown]
# ## EDA on new features

# %%
sns.heatmap(df[df.columns[2:]].corr())
plt.title('Correlation Heatmap', fontsize = 20)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10);
